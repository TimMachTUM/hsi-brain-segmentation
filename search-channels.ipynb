# %% [markdown]
# # Search

# %%
from dataset import build_hsi_testloader, get_wavelengths_from_metadata
from segmentation_util import build_segmentation_model, evaluate_model
import numpy as np
import torch
import random
import gc


def get_interval_from_wavelenths(start, end):
    wavelength_array = get_wavelengths_from_metadata()  # <--- your function
    indices = np.where((wavelength_array >= start) & (wavelength_array <= end))[0]
    return indices[0], indices[-1]


# Define the intervals:
red_interval = get_interval_from_wavelenths(600, 1000)
green_interval = get_interval_from_wavelenths(500, 600)
blue_interval = get_interval_from_wavelenths(400, 500)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

segmentation_model = build_segmentation_model(
    encoder="timm-regnetx_320", architecture="Linknet", device=device, in_channels=3
)
segmentation_model.load_state_dict(torch.load("models/serene-sweep-9.pth"))
segmentation_model.eval()  # put model in eval mode

num_random_samples = 50  # how many random picks to try
best_score = -1.0
best_bands = None
wavelengths = get_wavelengths_from_metadata()
for _ in range(num_random_samples):
    # Randomly pick one band from each interval
    red_band = random.randint(red_interval[0], red_interval[1])
    green_band = random.randint(green_interval[0], green_interval[1])
    blue_band = random.randint(blue_interval[0], blue_interval[1])

    print(
        f"Trying bands: red={wavelengths[red_band]}, green={wavelengths[green_band]}, blue={wavelengths[blue_band]}"
    )
    testloader_target = build_hsi_testloader(
        batch_size=1,
        rgb=True,
        rgb_channels=(red_band, green_band, blue_band),
    )

    # Evaluate the model on these chosen channels
    with torch.no_grad():
        _, _, _, _, dice_score = evaluate_model(
            segmentation_model, testloader_target, device, with_wandb=False
        )

    # Update best found so far
    if dice_score > best_score:
        best_score = dice_score
        best_bands = (red_band, green_band, blue_band)
        print(f"New best score: {best_score:.4f}, bands: {best_bands}")

    del testloader_target
    torch.cuda.empty_cache()
    gc.collect()

print(f"Best band combination: {best_bands} with Dice = {best_score:.4f}")
# Out:
# Trying bands: red=844.303, green=540.177, blue=425.947
# Precision: nan, Recall: 0.0699, F1 Score: 0.0846, Dice Score: 0.0846, Accuracy: 0.7891
# New best score: 0.0846, bands: (610, 192, 35)
# Trying bands: red=823.931, green=563.459, blue=475.423
# Precision: nan, Recall: 0.0683, F1 Score: 0.0803, Dice Score: 0.0803, Accuracy: 0.7849
# Trying bands: red=681.326, green=527.808, blue=421.582
# Precision: nan, Recall: 0.1319, F1 Score: 0.1217, Dice Score: 0.1217, Accuracy: 0.7927
# New best score: 0.1217, bands: (386, 175, 29)
# Trying bands: red=839.937, green=571.462, blue=438.316
# Precision: nan, Recall: 0.0588, F1 Score: 0.0736, Dice Score: 0.0736, Accuracy: 0.7858
# Trying bands: red=896.688, green=529.263, blue=482.698
# Precision: nan, Recall: 0.0358, F1 Score: 0.0510, Dice Score: 0.0510, Accuracy: 0.7837
# Trying bands: red=710.429, green=590.379, blue=425.22
# Precision: nan, Recall: 0.1690, F1 Score: 0.1430, Dice Score: 0.1430, Accuracy: 0.7911
# New best score: 0.1430, bands: (426, 261, 34)
# Trying bands: red=840.665, green=573.645, blue=497.977
# Precision: nan, Recall: 0.0530, F1 Score: 0.0677, Dice Score: 0.0677, Accuracy: 0.7842
# Trying bands: red=631.851, green=517.622, blue=437.589
# Precision: nan, Recall: 0.1397, F1 Score: 0.1259, Dice Score: 0.1259, Accuracy: 0.7938
# Trying bands: red=949.074, green=577.283, blue=453.595
# Precision: nan, Recall: 0.0242, F1 Score: 0.0379, Dice Score: 0.0379, Accuracy: 0.7850
# Trying bands: red=962.17, green=546.725, blue=487.791
# Precision: nan, Recall: 0.0307, F1 Score: 0.0460, Dice Score: 0.0460, Accuracy: 0.7853
# Trying bands: red=899.598, green=557.638, blue=439.771
# Precision: nan, Recall: 0.0386, F1 Score: 0.0545, Dice Score: 0.0545, Accuracy: 0.7845
# Trying bands: red=706.064, green=520.532, blue=444.137
# Precision: nan, Recall: 0.1495, F1 Score: 0.1338, Dice Score: 0.1338, Accuracy: 0.7924
# Trying bands: red=916.333, green=523.442, blue=446.32
# Precision: nan, Recall: 0.0407, F1 Score: 0.0572, Dice Score: 0.0572, Accuracy: 0.7854
# Trying bands: red=656.589, green=550.363, blue=471.785
# Precision: nan, Recall: 0.1286, F1 Score: 0.1225, Dice Score: 0.1225, Accuracy: 0.7889
# Trying bands: red=807.924, green=561.276, blue=466.692
# Precision: nan, Recall: 0.0820, F1 Score: 0.0913, Dice Score: 0.0913, Accuracy: 0.7868
# Trying bands: red=945.436, green=570.007, blue=479.06
# Precision: nan, Recall: 0.0261, F1 Score: 0.0399, Dice Score: 0.0399, Accuracy: 0.7843
# Trying bands: red=706.791, green=581.648, blue=431.041
# Precision: nan, Recall: 0.1534, F1 Score: 0.1312, Dice Score: 0.1312, Accuracy: 0.7926
# Trying bands: red=795.555, green=508.163, blue=416.489
# Precision: nan, Recall: 0.1350, F1 Score: 0.1253, Dice Score: 0.1253, Accuracy: 0.7962
# Trying bands: red=923.608, green=525.625, blue=418.672
# Precision: nan, Recall: 0.0522, F1 Score: 0.0694, Dice Score: 0.0694, Accuracy: 0.7874
# Trying bands: red=892.323, green=550.363, blue=444.137
# Precision: nan, Recall: 0.0395, F1 Score: 0.0557, Dice Score: 0.0557, Accuracy: 0.7848
# Trying bands: red=719.16, green=505.253, blue=443.409
# Precision: nan, Recall: 0.1593, F1 Score: 0.1389, Dice Score: 0.1389, Accuracy: 0.7950
# Trying bands: red=882.137, green=513.256, blue=421.582
# Precision: nan, Recall: 0.0607, F1 Score: 0.0765, Dice Score: 0.0765, Accuracy: 0.7877
# Trying bands: red=708.246, green=586.741, blue=403.393
# Precision: nan, Recall: 0.1859, F1 Score: 0.1581, Dice Score: 0.1581, Accuracy: 0.7847
# New best score: 0.1581, bands: (423, 256, 4)
# Trying bands: red=806.469, green=536.539, blue=455.778
# Precision: nan, Recall: 0.0864, F1 Score: 0.0955, Dice Score: 0.0955, Accuracy: 0.7886
# Trying bands: red=905.419, green=513.984, blue=468.147
# Precision: nan, Recall: 0.0438, F1 Score: 0.0597, Dice Score: 0.0597, Accuracy: 0.7846
# Trying bands: red=739.532, green=534.356, blue=416.489
# Precision: nan, Recall: 0.1251, F1 Score: 0.1215, Dice Score: 0.1215, Accuracy: 0.7928
# Trying bands: red=606.386, green=524.17, blue=409.941
# Precision: nan, Recall: 0.0862, F1 Score: 0.0941, Dice Score: 0.0941, Accuracy: 0.7861
# Trying bands: red=729.346, green=513.256, blue=483.426
# Precision: nan, Recall: 0.1585, F1 Score: 0.1458, Dice Score: 0.1458, Accuracy: 0.7896
# Trying bands: red=644.22, green=591.107, blue=454.323
# Precision: nan, Recall: 0.1714, F1 Score: 0.1485, Dice Score: 0.1485, Accuracy: 0.7870
# Trying bands: red=964.353, green=532.173, blue=482.698
# Precision: nan, Recall: 0.0293, F1 Score: 0.0437, Dice Score: 0.0437, Accuracy: 0.7842
# Trying bands: red=947.618, green=591.834, blue=454.323
# Precision: nan, Recall: 0.0388, F1 Score: 0.0554, Dice Score: 0.0554, Accuracy: 0.7861
# Trying bands: red=670.413, green=594.745, blue=444.137
# Precision: nan, Recall: 0.1723, F1 Score: 0.1524, Dice Score: 0.1524, Accuracy: 0.7895
# Trying bands: red=859.582, green=506.708, blue=462.326
# Precision: nan, Recall: 0.0569, F1 Score: 0.0723, Dice Score: 0.0723, Accuracy: 0.7859
# Trying bands: red=899.598, green=571.462, blue=431.041
# Precision: nan, Recall: 0.0384, F1 Score: 0.0547, Dice Score: 0.0547, Accuracy: 0.7853
# Trying bands: red=623.12, green=527.08, blue=467.419
# Precision: nan, Recall: 0.0981, F1 Score: 0.1039, Dice Score: 0.1039, Accuracy: 0.7871
# Trying bands: red=684.964, green=583.831, blue=465.964
# Precision: nan, Recall: 0.1678, F1 Score: 0.1459, Dice Score: 0.1459, Accuracy: 0.7866
# Trying bands: red=889.412, green=505.253, blue=480.516
# Precision: nan, Recall: 0.0456, F1 Score: 0.0617, Dice Score: 0.0617, Accuracy: 0.7853
# Trying bands: red=782.459, green=554.001, blue=455.05
# Precision: nan, Recall: 0.1093, F1 Score: 0.1100, Dice Score: 0.1100, Accuracy: 0.7903
# Trying bands: red=711.157, green=548.18, blue=408.486
# Precision: nan, Recall: 0.1470, F1 Score: 0.1315, Dice Score: 0.1315, Accuracy: 0.7908
# Trying bands: red=684.236, green=519.805, blue=428.13
# Precision: nan, Recall: 0.1508, F1 Score: 0.1299, Dice Score: 0.1299, Accuracy: 0.7947
# Trying bands: red=916.333, green=539.449, blue=401.21
# Precision: nan, Recall: 0.0699, F1 Score: 0.0852, Dice Score: 0.0852, Accuracy: 0.7895
# Trying bands: red=873.406, green=545.27, blue=425.22
# Precision: nan, Recall: 0.0526, F1 Score: 0.0690, Dice Score: 0.0690, Accuracy: 0.7862
# Trying bands: red=662.409, green=571.462, blue=498.705
# Precision: nan, Recall: 0.1214, F1 Score: 0.1312, Dice Score: 0.1312, Accuracy: 0.7818
# Trying bands: red=986.18, green=519.077, blue=409.941
# Precision: nan, Recall: 0.0759, F1 Score: 0.0912, Dice Score: 0.0912, Accuracy: 0.7912
# Trying bands: red=738.077, green=524.898, blue=444.137
# Precision: nan, Recall: 0.1318, F1 Score: 0.1246, Dice Score: 0.1246, Accuracy: 0.7929
# Trying bands: red=977.449, green=564.187, blue=458.688
# Precision: nan, Recall: 0.0350, F1 Score: 0.0515, Dice Score: 0.0515, Accuracy: 0.7860
# Trying bands: red=682.781, green=523.442, blue=436.134
# Precision: nan, Recall: 0.1422, F1 Score: 0.1274, Dice Score: 0.1274, Accuracy: 0.7930
# Trying bands: red=999.276, green=511.074, blue=409.941
# Precision: nan, Recall: 0.0879, F1 Score: 0.1004, Dice Score: 0.1004, Accuracy: 0.7928
# Trying bands: red=644.22, green=594.745, blue=495.795
# Precision: nan, Recall: 0.1806, F1 Score: 0.1702, Dice Score: 0.1702, Accuracy: 0.7867
# New best score: 0.1702, bands: (335, 267, 131)
# Trying bands: red=953.439, green=573.645, blue=487.791
# Precision: nan, Recall: 0.0249, F1 Score: 0.0383, Dice Score: 0.0383, Accuracy: 0.7842
# Best band combination: (335, 267, 131) with Dice = 0.1702
